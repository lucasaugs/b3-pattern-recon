# %%
import json
import os
import requests
import ipeadatapy as idpy

# %%
idpy.list_series("IPCA")
# Out:
#                     CODE                                               NAME
# 969        BM12_IPCA2012  IPCA - núcleo médias aparadas com suavização -...
# 970       BM12_IPCA20N12  IPCA -  núcleo médias aparadas sem suavização ...
# 971       BM12_IPCACOM12  IPCA - preços livres - comercializáveis - taxa...
# 972       BM12_IPCAEXC12  IPCA - núcleo por exclusão - sem monitorados e...
# 973    BM12_IPCAEXCEX212  IPCA - núcleo por exclusão - EX1 - taxa de var...
# 974     BM12_IPCAEXP1212  Expectativa média de Inflação - IPCA - taxa ac...
# 975      BM12_IPCAEXP612  Expectativa média de Inflação - IPCA - taxa an...
# 976      BM12_IPCANCOM12  IPCA - preços livres - não comercializáveis - ...
# 977        BM12_IPCAPL12            IPCA - preços livres - taxa de variação
# 978      BM12_IPCAPLBD12  IPCA - preços livres - bens duráveis - taxa de...
# 979     BM12_IPCAPLBND12  IPCA - preços livres - bens não duráveis - tax...
# ...

# %%
df_series = idpy.list_series(code="PRECOS_IPCAG")
df_series.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1 entries, 1094 to 1094
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CODE    1 non-null      object
#  1   NAME    1 non-null      object
# dtypes: object(2)
# memory usage: 24.0+ bytes

# %%
idpy.describe("BM12_IPCAEXP1212")
# Out:
#                Expectativa média de Inflação - IPCA - taxa acumulada para os próximos doze meses
# Name            Expectativa média de Inflação - IPCA - taxa ac...
# Code                                             BM12_IPCAEXP1212
# Big Theme                                          Macroeconômico
# Theme code                                                      9
# Source          Banco Central do Brasil, Boletim, Seção Ativid...
# Source acronym                            Bacen/Boletim/Ativ. Ec.
# Comment         As expectativas do mercado são projeções  elab...
# Last update                         2025-10-07T09:36:00.537-03:00
# Frequency                                                  Mensal
# Measure                                                  (% a.a.)
# Unit
# Status                                                          A

# %%
idpy.timeseries("BM12_IPCAEXP1212", yearGreaterThan=2012).to_csv(
    "data/ipea_expipca_2013_2024.csv", index=False
)

# %%
import pandas as pd

icb_df = pd.read_excel("data/icbbr.xlsx")
icb_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 152 entries, 0 to 151
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Período                 152 non-null    datetime64[ns]
#  1   IBC-Br                  152 non-null    float64
#  2   IBC-Br Agropecuária     152 non-null    float64
#  3   IBC-Br Indústria        152 non-null    float64
#  4   IBC-Br Serviços         152 non-null    float64
#  5   IBC-Br Impostos         152 non-null    float64
#  6   IBC-Br ex-Agropecuária  152 non-null    float64
# dtypes: datetime64[ns](1), float64(6)
# memory usage: 8.4 KB

# %%
icb_df.head()
# Out:
#      Período  IBC-Br  IBC-Br Agropecuária  IBC-Br Indústria  IBC-Br Serviços  \
# 0 2013-01-01   101.7                 83.4             115.6             98.4
# 1 2013-02-01   100.8                 83.5             113.4             97.7
# 2 2013-03-01   101.8                 83.2             113.6             98.5
# 3 2013-04-01   102.8                 84.4             116.5             99.1
# 4 2013-05-01   103.1                 84.6             116.9             99.5
#
#     IBC-Br Impostos  IBC-Br ex-Agropecuária
# 0             105.1                   102.8
# 1             102.6                   101.7
# 2             104.8                   102.5
# 3             104.7                   103.5
# 4             106.6                   104.1

# %%
icb_df.to_csv("data/icbbr.csv", index=False)
