# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

from correlations import (
    calculate_rolling_correlations,
    calculate_static_correlations,
    get_assets_data,
    get_macro_data,
    load_or_process_master_df,
    plot_rolling_windows_comparison,
)

# %%
master_df, top_assets = load_or_process_master_df()

# %%
from correlations import plot_top_n_uncorrelated_assets

plot_top_n_uncorrelated_assets(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="VALE3",
    top_n=3,
    window_sizes=[6, 12, 24],
    background_color="#f8f9fa",
    method="dcor",
)
# Out:
# Loaded rolling correlations from cache.
# Loaded rolling correlations from cache.
# Loaded rolling correlations from cache.

# %%
from correlations import plot_top_n_uncorrelated_assets

plot_top_n_uncorrelated_assets(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="VALE3",
    top_n=3,
    window_sizes=[6, 12, 24],
    background_color="#f8f9fa",
    method="dcor",
)
# Out:
# Loaded rolling correlations from cache.
# Loaded rolling correlations from cache.
# Loaded rolling correlations from cache.

# %%
from correlations import plot_top_n_uncorrelated_assets

plot_top_n_uncorrelated_assets(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="VALE3",
    top_n=3,
    window_sizes=[6, 12, 24],
    background_color="#f8f9fa",
)
# Out:
# Loaded rolling correlations from cache.
# Loaded rolling correlations from cache.
# Loaded rolling correlations from cache.

# %%
master_df, top_assets = load_or_process_master_df()

# %%
plot_rolling_windows_comparison(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="PETR4",
    target_macro="macro_dollar_var",
    window_sizes=[6],
    background_color="#f8f9fa",
)
# Out:
# Loaded rolling correlations from cache.

# %%
plot_rolling_windows_comparison(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="PETR4",
    target_macro="macro_dollar_var",
    window_sizes=[6],
    background_color="#f8f9fa",
    method="dcor",
)
# Out:
# Loaded rolling correlations from cache.

# %%
from correlations import plot_top_n_correlated_assets

plot_top_n_correlated_assets(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="VALE3",
    top_n=3,
    window_sizes=[6],
    background_color="#f8f9fa",
)
# Out:
# Loaded rolling correlations from cache.

# %%
from correlations import plot_top_n_correlated_assets

plot_top_n_correlated_assets(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="VALE3",
    top_n=3,
    window_sizes=[6],
    background_color="#f8f9fa",
    method="dcor",
)
# Out:
# Loaded rolling correlations from cache.

# %%
from correlations import plot_top_n_uncorrelated_assets

plot_top_n_uncorrelated_assets(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="VALE3",
    top_n=3,
    window_sizes=[6],
    background_color="#f8f9fa",
)
# Out:
# Loaded rolling correlations from cache.

# %%
from correlations import plot_top_n_uncorrelated_assets

plot_top_n_uncorrelated_assets(
    master_data=master_df,
    asset_list=top_assets,
    target_asset="VALE3",
    top_n=3,
    window_sizes=[6],
    background_color="#f8f9fa",
    method="dcor",
)
# Out:
# Loaded rolling correlations from cache.
